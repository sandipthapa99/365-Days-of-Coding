# %%
import matplotlib.pyplot as plt 
# x axis 
x = [-11,-11,-9,-8,-6,11,11,5,4,5,6,7,8,9,10,
     11,9,6,5,3,2,1.5,1.5,2.5,-2,-4,-5,-6,-7,
     -8.5,-9,-9,-6.5,-6,-5,-7.5,-9,-10,-10,-11] 
# corresponding y axis 
y = [4,5,9,10,11,11,7,7,-3,-5,-6,-7,-7,-6,-4,
     -4,-9,-11,-11,-9,-7,-5,-3,7,7,-6,-9.5,
     -10.5,-10.5,-10,-9,-6,-4,-3,7,7,6.5,5,4,4]
# plotting the points  
plt.plot(x, y) 
plt.title('Pi day') 
plt.show()
